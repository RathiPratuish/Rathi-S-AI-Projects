# %% [markdown]
# NN Project - Part A

# %% [markdown]
# Part A - Q1 A - Read the ‘Signals.csv’ as DatFrame and import required libraries.

# %% [markdown]
# Import Libraries

# %%
import numpy as np       # this library is used for numeric operations
import pandas as pd      # this library is used for data operations

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Ignore the warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Read the data

# %%
# Read the 'Signal.csv' file
signal_df = pd.read_csv('/content/drive/MyDrive/Neural NW and Deep Lrng/Part-+1%2C2%263+-+Signal.csv')

# %%
# Display the first 5 rows of the csv file
signal_df.head()
# Out:
#    Parameter 1  Parameter 2  Parameter 3  Parameter 4  Parameter 5  \
# 0          7.4         0.70         0.00          1.9        0.076
# 1          7.8         0.88         0.00          2.6        0.098
# 2          7.8         0.76         0.04          2.3        0.092
# 3         11.2         0.28         0.56          1.9        0.075
# 4          7.4         0.70         0.00          1.9        0.076
#
#    Parameter 6  Parameter 7  Parameter 8  Parameter 9  Parameter 10  \
# 0         11.0         34.0       0.9978         3.51          0.56
# 1         25.0         67.0       0.9968         3.20          0.68
# 2         15.0         54.0       0.9970         3.26          0.65
# 3         17.0         60.0       0.9980         3.16          0.58
# 4         11.0         34.0       0.9978         3.51          0.56
#
#    Parameter 11  Signal_Strength
# 0           9.4                5
# 1           9.8                5
# 2           9.8                5
# ...

# %% [markdown]
# Part A - Q1 B - Check for missing values and print percentage for each attribute.

# %% [markdown]
# Check data types

# %%
signal_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Parameter 1      1599 non-null   float64
#  1   Parameter 2      1599 non-null   float64
#  2   Parameter 3      1599 non-null   float64
#  3   Parameter 4      1599 non-null   float64
#  4   Parameter 5      1599 non-null   float64
#  5   Parameter 6      1599 non-null   float64
#  6   Parameter 7      1599 non-null   float64
#  7   Parameter 8      1599 non-null   float64
#  8   Parameter 9      1599 non-null   float64
#  9   Parameter 10     1599 non-null   float64
#  10  Parameter 11     1599 non-null   float64
#  11  Signal_Strength  1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# There are 1599 rows and 12 columns in the dataset. Out of 12 columns, only one column namely - 'Signal_Strength' is of type int, the remaining columns are of type float.

# %% [markdown]
# Shape of the dataset

# %%
signal_df.shape
# Out:
# (1599, 12)

# %% [markdown]
# Description of data in the dataframe

# %%
# Five point summary of the numerical attributes
signal_df.describe(include='all').T
# Out:
#                   count       mean        std      min      25%       50%  \
# Parameter 1      1599.0   8.319637   1.741096  4.60000   7.1000   7.90000
# Parameter 2      1599.0   0.527821   0.179060  0.12000   0.3900   0.52000
# Parameter 3      1599.0   0.270976   0.194801  0.00000   0.0900   0.26000
# Parameter 4      1599.0   2.538806   1.409928  0.90000   1.9000   2.20000
# Parameter 5      1599.0   0.087467   0.047065  0.01200   0.0700   0.07900
# Parameter 6      1599.0  15.874922  10.460157  1.00000   7.0000  14.00000
# Parameter 7      1599.0  46.467792  32.895324  6.00000  22.0000  38.00000
# Parameter 8      1599.0   0.996747   0.001887  0.99007   0.9956   0.99675
# Parameter 9      1599.0   3.311113   0.154386  2.74000   3.2100   3.31000
# Parameter 10     1599.0   0.658149   0.169507  0.33000   0.5500   0.62000
# Parameter 11     1599.0  10.422983   1.065668  8.40000   9.5000  10.20000
# Signal_Strength  1599.0   5.636023   0.807569  3.00000   5.0000   6.00000
#
# ...

# %% [markdown]
# 1.  Parameter 1 varies from 4.60 to 15.90.The mean is 8.31.
# 2.  Parameter 2 varies from 0.12 to 1.58. The mean is 0.53.
# 3.  Parameter 3 varies from 0.0 to 1.0. The mean is 0.27.
# 4.  Parameter 4 varies from 0.90 to 15.50. The mean is 2.52.
# 5.  Parameter 5 varies from 0.01 to 0.61. The mean is 0.09.
# 6.  Parameter 6 varies from 1.00 to 72.00. The mean is 15.89.
# 7.  Parameter 7 varies from 6.00 to 289.00. The mean is 46.83
# 8.  Parameter 8 varies from 0.99 to 1.00. The mean is 0.997.
# 9.  Parameter 9 varies from 2.74 to 4.01. The mean is 3.31.
# 10. Parameter 10 varies from 0.33 to 2.00. The mean is 0.66.
# 11. Parameter 11 varies from 8.40 to 14.90. The mean is 10.43.
# 12. Signal_Strength varies from 3.00 to 8.00. The mean is 5.62.

# %% [markdown]
# Least Standard Deviation is 0.001869 for Parameter 8.
# Most Standard Deviation is 33.408946 for Parameter 7.

# %% [markdown]
# Check if there are null values

# %%
signal_df.isnull().sum()
# Out:
# Parameter 1        0
# Parameter 2        0
# Parameter 3        0
# Parameter 4        0
# Parameter 5        0
# Parameter 6        0
# Parameter 7        0
# Parameter 8        0
# Parameter 9        0
# Parameter 10       0
# Parameter 11       0
# Signal_Strength    0
# dtype: int64

# %% [markdown]
# There are no null values in the dataset.

# %% [markdown]
# Calculating the percentage for each attribute

# %%
signal_df_missing = signal_df.isna()

# %%
signal_df_missing.head()
# Out:
#    Parameter 1  Parameter 2  Parameter 3  Parameter 4  Parameter 5  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    Parameter 6  Parameter 7  Parameter 8  Parameter 9  Parameter 10  \
# 0        False        False        False        False         False
# 1        False        False        False        False         False
# 2        False        False        False        False         False
# 3        False        False        False        False         False
# 4        False        False        False        False         False
#
#    Parameter 11  Signal_Strength
# 0         False            False
# 1         False            False
# 2         False            False
# ...

# %%
signal_df_num_missing = signal_df_missing.sum()

# %%
signal_df_num_missing
# Out:
# Parameter 1        0
# Parameter 2        0
# Parameter 3        0
# Parameter 4        0
# Parameter 5        0
# Parameter 6        0
# Parameter 7        0
# Parameter 8        0
# Parameter 9        0
# Parameter 10       0
# Parameter 11       0
# Signal_Strength    0
# dtype: int64

# %% [markdown]
# Turning this result into a percentage

# %%
len(signal_df)
# Out:
# 1599

# %%
signal_df_num_missing / len(signal_df)
# Out:
# Parameter 1        0.0
# Parameter 2        0.0
# Parameter 3        0.0
# Parameter 4        0.0
# Parameter 5        0.0
# Parameter 6        0.0
# Parameter 7        0.0
# Parameter 8        0.0
# Parameter 9        0.0
# Parameter 10       0.0
# Parameter 11       0.0
# Signal_Strength    0.0
# dtype: float64

# %% [markdown]
# The percentage is 0.0 for all attributes, as none of the rows are having missing values.

# %% [markdown]
# Part A - Q1 C - Check for presence of duplicate records in the dataset and impute with appropriate method.

# %% [markdown]
# Check for duplicates

# %%
signal_df.duplicated().sum()
# Out:
# 240

# %% [markdown]
# There are 240 duplicate rows.

# %%
# Selecting duplicate rows except first
# occurrence based on all columns
signal_df_duplicate = signal_df[signal_df.duplicated()]

print("Duplicate Rows :")

# Print the resultant Dataframe
signal_df_duplicate
# Out:
# Duplicate Rows :
#       Parameter 1  Parameter 2  Parameter 3  Parameter 4  Parameter 5  \
# 4             7.4        0.700         0.00         1.90        0.076
# 11            7.5        0.500         0.36         6.10        0.071
# 27            7.9        0.430         0.21         1.60        0.106
# 40            7.3        0.450         0.36         5.90        0.074
# 65            7.2        0.725         0.05         4.65        0.086
# ...           ...          ...          ...          ...          ...
# 1563          7.2        0.695         0.13         2.00        0.076
# 1564          7.2        0.695         0.13         2.00        0.076
# 1567          7.2        0.695         0.13         2.00        0.076
# 1581          6.2        0.560         0.09         1.70        0.053
# 1596          6.3        0.510         0.13         2.30        0.076
#
#       Parameter 6  Parameter 7  Parameter 8  Parameter 9  Parameter 10  \
# ...

# %% [markdown]
# Removal of duplicate rows

# %%
# dropping ALL duplicate values
signal_df.drop_duplicates(keep="first", inplace=True)

# %% [markdown]
# Check for duplicates again

# %%
signal_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Check shape of the dataset again

# %%
signal_df.shape
# Out:
# (1359, 12)

# %% [markdown]
# The duplicate rows (240) have been removed now. Hence, the number of rows in the dataframe is 1359 now.

# %% [markdown]
# Duplicate records do not add any value or information while using them in a model and would rather slow down the processing. Therefore, it is better to remove duplicates, before feeding the data to the model.

# %% [markdown]
# Part A - Q1 D - Visualise distribution of the target variable.

# %% [markdown]
# Exploratory Data Analysis

# %% [markdown]
# Univariate analysis - Here, countplot, distplot and histplot are used to visualise distribution of the target variable.

# %%
# count plot on single numerical variable
sns.countplot(x ='Signal_Strength', data = signal_df)

# Show the plot
plt.show()

# %% [markdown]
# Distplot

# %%
sns.distplot(signal_df["Signal_Strength"]);

# %%
sns.histplot(signal_df["Signal_Strength"]);

# %% [markdown]
# The maximum count (around 577) is for Signal_Strength = 5, followed by Signal_Strength = 6 (around 535).

# %%
signal_df['Signal_Strength'].value_counts()
# Out:
# 5    577
# 6    535
# 7    167
# 4     53
# 8     17
# 3     10
# Name: Signal_Strength, dtype: int64

# %% [markdown]
# Bivariate Analysis

# %% [markdown]
# Finding the correlation of the various parameters.

# %%
signal_df.corr()
# Out:
#                  Parameter 1  Parameter 2  Parameter 3  Parameter 4  \
# Parameter 1         1.000000    -0.255124     0.667437     0.111025
# Parameter 2        -0.255124     1.000000    -0.551248    -0.002449
# Parameter 3         0.667437    -0.551248     1.000000     0.143892
# Parameter 4         0.111025    -0.002449     0.143892     1.000000
# Parameter 5         0.085886     0.055154     0.210195     0.026656
# Parameter 6        -0.140580    -0.020945    -0.048004     0.160527
# Parameter 7        -0.103777     0.071701     0.047358     0.201038
# Parameter 8         0.670195     0.023943     0.357962     0.324522
# Parameter 9        -0.686685     0.247111    -0.550310    -0.083143
# Parameter 10        0.190269    -0.256948     0.326062    -0.011837
# Parameter 11       -0.061596    -0.197812     0.105108     0.063281
# Signal_Strength     0.119024    -0.395214     0.228057     0.013640
#
#                  Parameter 5  Parameter 6  Parameter 7  Parameter 8  \
# ...

# %%
fig, ax = plt.subplots(figsize=(20,20))         # Sample figsize in inches
ax = sns.heatmap(signal_df.corr(),annot=True);

# %% [markdown]
# We want to know about the various variables that have strong positive correlation between them, hence trying to find out the columns that have a correlation > 0.7

# %%
signal_df.corr()[signal_df.corr()>0.7]
# Out:
#                  Parameter 1  Parameter 2  Parameter 3  Parameter 4  \
# Parameter 1              1.0          NaN          NaN          NaN
# Parameter 2              NaN          1.0          NaN          NaN
# Parameter 3              NaN          NaN          1.0          NaN
# Parameter 4              NaN          NaN          NaN          1.0
# Parameter 5              NaN          NaN          NaN          NaN
# Parameter 6              NaN          NaN          NaN          NaN
# Parameter 7              NaN          NaN          NaN          NaN
# Parameter 8              NaN          NaN          NaN          NaN
# Parameter 9              NaN          NaN          NaN          NaN
# Parameter 10             NaN          NaN          NaN          NaN
# Parameter 11             NaN          NaN          NaN          NaN
# Signal_Strength          NaN          NaN          NaN          NaN
#
#                  Parameter 5  Parameter 6  Parameter 7  Parameter 8  \
# ...

# %% [markdown]
# None of the fields are strongly positively correlated.

# %% [markdown]
# We want to know about the various variables that have strong negative correlation between them, hence trying to find out the columns that have a correlation around -0.8.

# %%
signal_df.corr()[signal_df.corr()<-0.8]
# Out:
#                  Parameter 1  Parameter 2  Parameter 3  Parameter 4  \
# Parameter 1              NaN          NaN          NaN          NaN
# Parameter 2              NaN          NaN          NaN          NaN
# Parameter 3              NaN          NaN          NaN          NaN
# Parameter 4              NaN          NaN          NaN          NaN
# Parameter 5              NaN          NaN          NaN          NaN
# Parameter 6              NaN          NaN          NaN          NaN
# Parameter 7              NaN          NaN          NaN          NaN
# Parameter 8              NaN          NaN          NaN          NaN
# Parameter 9              NaN          NaN          NaN          NaN
# Parameter 10             NaN          NaN          NaN          NaN
# Parameter 11             NaN          NaN          NaN          NaN
# Signal_Strength          NaN          NaN          NaN          NaN
#
#                  Parameter 5  Parameter 6  Parameter 7  Parameter 8  \
# ...

# %% [markdown]
# None of the fields are strongly negatively correlated.

# %%
# Correlation of all numerical variables (float) - 'Parameter 1','Parameter 2','Parameter 3','Parameter 4','Parameter 5','Parameter 6',
# 'Parameter 7','Parameter 8', 'Parameter 9', 'Parameter 10', 'Parameter 11' with the variable 'Signal_Strength'
corr1=signal_df['Parameter 1'].corr(signal_df['Signal_Strength'])
print("Parameter 1 and Signal_Strength corr is ",corr1)

corr2 = signal_df['Parameter 2'].corr(signal_df['Signal_Strength'])
print("Parameter 2 and Signal_Strength corr is ",corr2)

corr3 = signal_df['Parameter 3'].corr(signal_df['Signal_Strength'])
print("Parameter 3 and Signal_Strength corr is ",corr3)

corr4 = signal_df['Parameter 4'].corr(signal_df['Signal_Strength'])
print("Parameter 4 and Signal_Strength corr is ",corr4)

corr5 = signal_df['Parameter 5'].corr(signal_df['Signal_Strength'])
print("Parameter 5 and Signal_Strength corr is ",corr5)

corr6 = signal_df['Parameter 6'].corr(signal_df['Signal_Strength'])
print("Parameter 6 and Signal_Strength corr is ",corr6)

corr7 = signal_df['Parameter 7'].corr(signal_df['Signal_Strength'])
print("Parameter 7 and Signal_Strength corr is ",corr7)

corr8 = signal_df['Parameter 8'].corr(signal_df['Signal_Strength'])
print("Parameter 8 and Signal_Strength corr is ",corr8)

corr9 = signal_df['Parameter 9'].corr(signal_df['Signal_Strength'])
print("Parameter 9 and Signal_Strength corr is ",corr9)

corr10 = signal_df['Parameter 10'].corr(signal_df['Signal_Strength'])
print("Parameter 10 and Signal_Strength corr is ",corr10)

corr11 = signal_df['Parameter 11'].corr(signal_df['Signal_Strength'])
print("Parameter 11 and Signal_Strength corr is ",corr11)
# Out:
# Parameter 1 and Signal_Strength corr is  0.1190236656134977
# Parameter 2 and Signal_Strength corr is  -0.3952136890098405
# Parameter 3 and Signal_Strength corr is  0.22805745919929968
# Parameter 4 and Signal_Strength corr is  0.013640470048445876
# Parameter 5 and Signal_Strength corr is  -0.13098841286642668
# Parameter 6 and Signal_Strength corr is  -0.050462766805025774
# Parameter 7 and Signal_Strength corr is  -0.17785536568029603
# Parameter 8 and Signal_Strength corr is  -0.18425165011902409
# Parameter 9 and Signal_Strength corr is  -0.05524511495867183
# Parameter 10 and Signal_Strength corr is  0.2488351355778882
# Parameter 11 and Signal_Strength corr is  0.4803428980015536

# %% [markdown]
# Parameter 11 has the maximum positive correlation
# (0.48) with the dependent variable Signal_Strength, followed by Parameter 10 (0.25).
#
# Parameter 2 has the maximum negative correlation (-0.39) with the independent variable Signal_Strength, followed by Parameter 8 (-0.18) and Parameter 7 (-0.17) respectively.

# %% [markdown]
# Pair Plot

# %%
sns.pairplot(signal_df,diag_kind="kde")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Visualize the distribution of target variable
sns.distplot(signal_df['Signal_Strength'])
plt.show()
print('Distribution of target variable- Signal_Strength')

print('The mean is ',signal_df['Signal_Strength'].mean())
print('The median is ',signal_df['Signal_Strength'].median())
print('The mode is ',signal_df['Signal_Strength'].mode()[0])

print('The minimum value is ',signal_df['Signal_Strength'].min())
print('The maximum value is ',signal_df['Signal_Strength'].max())

print('The standard deviation is ',signal_df['Signal_Strength'].std())
print('The skewness is ',signal_df['Signal_Strength'].skew())
# Out:
# Distribution of target variable- Signal_Strength
# The mean is  5.6232523914643116
# The median is  6.0
# The mode is  5
# The minimum value is  3
# The maximum value is  8
# The standard deviation is  0.8235780017165553
# The skewness is  0.19240658731658308

# %% [markdown]
# The skewness is around 0.192 for the target variable. Hence, the distribution is approximately symmetric.

# %%
print(signal_df.columns)
# Out:
# Index(['Parameter 1', 'Parameter 2', 'Parameter 3', 'Parameter 4',
#        'Parameter 5', 'Parameter 6', 'Parameter 7', 'Parameter 8',
#        'Parameter 9', 'Parameter 10', 'Parameter 11', 'Signal_Strength'],
#       dtype='object')

# %% [markdown]
# Check for outliers

# %%
numeric_columns = signal_df.select_dtypes(['int','float']).columns
numeric_columns
# Out:
# Index(['Parameter 1', 'Parameter 2', 'Parameter 3', 'Parameter 4',
#        'Parameter 5', 'Parameter 6', 'Parameter 7', 'Parameter 8',
#        'Parameter 9', 'Parameter 10', 'Parameter 11', 'Signal_Strength'],
#       dtype='object')

# %%
plt.figure(figsize=(15,40))
c = 1
for i in numeric_columns:
    plt.subplot(21,2,c)
    sns.boxplot(data=signal_df, y=i)
    plt.title(f'Box Plot: {i}')
    plt.subplot(21,2,c+1)
    sns.histplot(data=signal_df, x=i, kde=True)
    plt.title(f'Histogram: {i}')
    c += 2

plt.tight_layout();

# %% [markdown]
# All the fields here have outliers. Hence, outlier treatment needs to be done here.
# Outliers not only hamper data quality but also affect the output in case of prediction models. Prediction tools like Neural Networks (NN) need outlier free dataset in order to achieve better generalization of the network, as errors in the dataset hinder the modelling process and produce misleading results.

# %%
# Checking whether outliers are present or not
l = len(signal_df)
col = list(signal_df.columns)
#col.remove('condition')
for i in np.arange(len(col)):
    sns.boxplot(x= signal_df[col[i]], color='blue')
    plt.show()
    print('Boxplot of ',col[i])
    #calculating the outiers in attribute
    Q1 = signal_df[col[i]].quantile(0.25)
    Q2 = signal_df[col[i]].quantile(0.50)
    Q3 = signal_df[col[i]].quantile(0.75)
    IQR = Q3 - Q1
    L_W = (Q1 - 1.5 *IQR)
    U_W = (Q3 + 1.5 *IQR)
    print('Q1 is : ',Q1)
    print('Q2 is : ',Q2)
    print('Q3 is : ',Q3)
    print('IQR is:',IQR)
    print('Lower Whisker, Upper Whisker : ',L_W,',',U_W)
    bools = (signal_df[col[i]] < (Q1 - 1.5 *IQR)) |(signal_df[col[i]] > (Q3 + 1.5 * IQR))
    print('Out of ',l,' rows in data, number of outliers are:',bools.sum())   #calculating the number of outliers
# Out:
# Boxplot of  Parameter 1
# Q1 is :  7.1
# Q2 is :  7.9
# Q3 is :  9.2
# IQR is: 2.0999999999999996
# Lower Whisker, Upper Whisker :  3.95 , 12.349999999999998
# Out of  1359  rows in data, number of outliers are: 41
# Boxplot of  Parameter 2
# Q1 is :  0.39
# Q2 is :  0.52
# Q3 is :  0.64
# IQR is: 0.25
# Lower Whisker, Upper Whisker :  0.015000000000000013 , 1.0150000000000001
# Out of  1359  rows in data, number of outliers are: 19
# Boxplot of  Parameter 3
# Q1 is :  0.09
# Q2 is :  0.26
# Q3 is :  0.43
# IQR is: 0.33999999999999997
# Lower Whisker, Upper Whisker :  -0.42000000000000004 , 0.94
# Out of  1359  rows in data, number of outliers are: 1
# Boxplot of  Parameter 4
# Q1 is :  1.9
# Q2 is :  2.2
# Q3 is :  2.6
# IQR is: 0.7000000000000002
# Lower Whisker, Upper Whisker :  0.8499999999999996 , 3.6500000000000004
# Out of  1359  rows in data, number of outliers are: 126
# Boxplot of  Parameter 5
# Q1 is :  0.07
# Q2 is :  0.079
# Q3 is :  0.091
# IQR is: 0.02099999999999999
# ...

# %% [markdown]
# Parameters have the following number of outliers.
#
#
# 1.   Parameter 1     : 41
# 2.   Parameter 2     : 19
# 3.   Parameter 3     : 1
# 4.   Parameter 4     : 126
# 5.   Parameter 5     : 87
# 6.   Parameter 6     : 26
# 7.   Parameter 7     : 45
# 8.   Parameter 8     : 35
# 9.   Parameter 9     : 28
# 10.  Parameter 10    : 55
# 11.  Parameter 11    : 12
# 12.  Signal_Strength : 27

# %% [markdown]
# Parameter 4 has the maximum outliers (around 126).

# %% [markdown]
# Outlier Treatment

# %%
#  function to treat outliers
def detect_treate_outliers(df,operation):
    cols=[]
    IQR_list=[]
    lower_boundary_list=[]
    upper_boundary_list=[]
    outliers_count=[]
    for col in df.columns:
        #print('col',col)
        if((df[col].dtype =='int64' or df[col].dtype =='float64') and (col != 'HR')):
            #print('Inside if')
            IQR = df[col].quantile(0.75) - df[col].quantile(0.25)
            lower_boundary = df[col].quantile(0.25) - (1.5 * IQR)
            upper_boundary = df[col].quantile(0.75) + (1.5 * IQR)
            up_cnt = df[df[col]>upper_boundary][col].shape[0]
            #print('Upper count=',up_cnt)
            lw_cnt = df[df[col]<lower_boundary][col].shape[0]
            #print('lower count=',lw_cnt)
            if(up_cnt+lw_cnt) > 0:
                cols.append(col)
                IQR_list.append(IQR)
                lower_boundary_list.append(lower_boundary)
                upper_boundary_list.append(upper_boundary)
                outliers_count.append(up_cnt+lw_cnt)
                if operation == 'update':
                    df.loc[df[col] > upper_boundary,col] = upper_boundary
                    df.loc[df[col] < lower_boundary,col] = lower_boundary
                else:
                    pass
            else:
                pass
   #print('cols=',cols)
   # print('IQR_list=',IQR_list)
   # print('lower_boundary_list=',lower_boundary_list)
   # print('upper_boundary_list=',upper_boundary_list)
   # print('outliers_count=',outliers_count)
    ndf = pd.DataFrame(list(zip(cols,IQR_list,lower_boundary_list,upper_boundary_list,outliers_count)),columns=['Features','IQR','Lower Boundary','Upper Boundary','Outlier Count'])
    #print('Data=',ndf)
    #print('Columns having outliers=',cols)
    if operation == 'update':
        return (len(cols),df)
    else:
        return (len(cols),ndf)

# %%
#Removing outliers by replacing the data below lower whisker with it and above upper whisker with it respectively.
count,df=detect_treate_outliers(signal_df,'update')
if count>0:
    print('Updating dataset')
    signal_df=df
# Out:
# Updating dataset

# %% [markdown]
# Checking the outliers after outlier treatment

# %%
# Checking the status of outliers after treatment
l = len(signal_df)
col = list(signal_df.columns)
#col.remove('condition')
for i in np.arange(len(col)):
    sns.boxplot(x= signal_df[col[i]], color='blue')
    plt.show()
    print('Boxplot of ',col[i])
    #calculating the outiers in attribute
    Q1 = signal_df[col[i]].quantile(0.25)
    Q2 = signal_df[col[i]].quantile(0.50)
    Q3 = signal_df[col[i]].quantile(0.75)
    IQR = Q3 - Q1
    L_W = (Q1 - 1.5 *IQR)
    U_W = (Q3 + 1.5 *IQR)
    print('Q1 is : ',Q1)
    print('Q2 is : ',Q2)
    print('Q3 is : ',Q3)
    print('IQR is:',IQR)
    print('Lower Whisker, Upper Whisker : ',L_W,',',U_W)
    bools = (signal_df[col[i]] < (Q1 - 1.5 *IQR)) |(signal_df[col[i]] > (Q3 + 1.5 * IQR))
    print('Out of ',l,' rows in data, number of outliers are:',bools.sum())   #calculating the number of outliers
# Out:
# Boxplot of  Parameter 1
# Q1 is :  7.1
# Q2 is :  7.9
# Q3 is :  9.2
# IQR is: 2.0999999999999996
# Lower Whisker, Upper Whisker :  3.95 , 12.349999999999998
# Out of  1359  rows in data, number of outliers are: 0
# Boxplot of  Parameter 2
# Q1 is :  0.39
# Q2 is :  0.52
# Q3 is :  0.64
# IQR is: 0.25
# Lower Whisker, Upper Whisker :  0.015000000000000013 , 1.0150000000000001
# Out of  1359  rows in data, number of outliers are: 0
# Boxplot of  Parameter 3
# Q1 is :  0.09
# Q2 is :  0.26
# Q3 is :  0.43
# IQR is: 0.33999999999999997
# Lower Whisker, Upper Whisker :  -0.42000000000000004 , 0.94
# Out of  1359  rows in data, number of outliers are: 0
# Boxplot of  Parameter 4
# Q1 is :  1.9
# Q2 is :  2.2
# Q3 is :  2.6
# IQR is: 0.7000000000000002
# Lower Whisker, Upper Whisker :  0.8499999999999996 , 3.6500000000000004
# Out of  1359  rows in data, number of outliers are: 0
# Boxplot of  Parameter 5
# Q1 is :  0.07
# Q2 is :  0.079
# Q3 is :  0.091
# IQR is: 0.02099999999999999
# ...

# %% [markdown]
#  Outliers increase the variability in your data, which decreases statistical power. Consequently, excluding outliers can cause your results to become statistically significant.
#  As the outliers have been removed, further checking the correlation between the attributes.

# %%
# Analyzing correlation between the attributes, after removal of outliers.
b_corr=signal_df.corr()
plt.subplots(figsize =(12, 7))
sns.heatmap(b_corr,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# The strong correlation values lie between ± 0.50 and ± 1.
#
# 1.   Parameter 1 is strongly positively correlated with Parameter 3 (0.67).
# 2.   Parameter 1 is strongly positively correlated with Parameter 8 (0.67).
# 3.   Parameter 1 is strongly negatively correlated with Parameter 9 (-0.69).
# 4.   Parameter 6 is strongly positively correlated with Parameter 7 (0.69).

# %% [markdown]
# The parameters are not highly correlated i.e. 0.8 or above. Hence, the features are not eliminated here.
# Multicollinearity is not a problem in Neural Networks. The main reason for that is that multicollinearity is an issue which only arises, when we have linear relationships. Neural Networks with more than 1 hidden layer already does not qualify for this case.

# %% [markdown]
# Check the feature importance of the given attributes.

# %%
# !pip install scikit-learn

# %%
from sklearn.ensemble import ExtraTreesClassifier
# ExtraTreesClassifier class implements a meta estimator that fits
# a number of randomized decision trees (a.k.a. extra-trees) on various
# sub-samples of the dataset and uses averaging to improve the predictive
# accuracy and control over-fitting.

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ExtraTreeClassifier is an extremely randomized version of DecisionTreeClassifier meant to be used internally as part of the ExtraTreesClassifier ensemble.

# %%
# Feature Importance

# Independent variables
X=signal_df.drop('Signal_Strength',axis=1)

# Target variable
Y=signal_df['Signal_Strength']

# %%
import matplotlib.pyplot as plt
# model = ExtraTreesClassifier()
# Change the classifier type
model = DecisionTreeClassifier()

# %% [markdown]
# The DecisionTreeClassifier model expects the target variable y to be a categorical variable.

# %% [markdown]
# Convert the target variable to a categorical variable:

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
Y = le.fit_transform(Y)

# %% [markdown]
# Print the type of the target variable Y

# %%
print(type(Y))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# Investigate the values of the target variable:

# %%
print(np.unique(Y))
# Out:
# [0 1 2 3 4 5]

# %%
model.fit(X,Y)
# Model fitting is a measure of how well a machine learning model
# generalizes to similar data to that on which it was trained.
# Out:
# DecisionTreeClassifier()

# %%
# using inbuilt class "feature_importances_" of tree based classifiers
# The impurity-based feature importances.The higher, the more important
# the feature. The importance of a feature is computed as the (normalized)
# total reduction of the criterion brought by that feature.
# It is also known as the Gini importance.
print(model.feature_importances_)
# Out:
# [0.06378222 0.11055095 0.06682896 0.05854921 0.07507856 0.058976
#  0.12487841 0.07188258 0.07799367 0.1145372  0.17694224]

# %%
#plotting graph of feature importances
ftre_imp = pd.Series(model.feature_importances_, index=X.columns)
ftre_imp.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# Parameter 11 has the highest feature importance and hence, is the most relevant parameter.

# %% [markdown]
# Part A - Q1 E - Share insights from the initial data analysis (at least 2).

# %% [markdown]
# Insights from the initial data analysis:
#
# a. Distribution of Signal Strength: According to the given dataset, the majority of the variable "Signal_Strength" is located between 5 and 6. For 'Signal_Strength' 5 and 6, the counts are 577 and 535, respectively, which is a far higher count.
# As a result, we note that the dataset exhibits an imbalance with a bias towards these particular values in the field "Signal_Strength."
#
# b. Range and Variability of Parameters: The statistical analysis of the several variables (parameters 1 through 11) shows that the standard deviation and ranges of each vary. For instance, Parameter 7 in this dataset has a standard deviation of 32.90, which is rather high, whereas Parameter 6 has a standard deviation of 10.46. This suggests more variation in the data, which could therefore affect the estimation of signal strength. As a result, when training the model, we would need to be cautious with these values.

# %% [markdown]
# Parameter 11 has the maximum positive correlation
# (0.48) with the target variable Signal_Strength, followed by Parameter 10 (0.25).
#
# Parameter 2 has the maximum negative correlation (-0.39) with the target variable Signal_Strength, followed by Parameter 8 (-0.18) and Parameter 7 (-0.17) respectively.
#
# Distribution of target variable- Signal_Strength
#
# 1. Mean     5.620676968359088
# 2. Median   6.0
# 3. Mode     5.0
# 4. Minimum value  3.5
# 5. Maximum value  7.5
# 6. Standard Deviation   0.7963507421717632
# 7. Skewness             0.1771681345358897
#
# If skewness is between -0.5 and 0.5, the distribution is approximately symmetric.
# Hence, the distribution is approximately symmetric for the target variable 'Signal_Strength'.

# %% [markdown]
# Part A - Q2 A - Split the data into X & Y.

# %%
# to count the number of classes in output
signal_df['Signal_Strength'].value_counts()
# Out:
# 5.0    577
# 6.0    535
# 7.0    167
# 4.0     53
# 7.5     17
# 3.5     10
# Name: Signal_Strength, dtype: int64

# %%
# Independent variables
X=signal_df.drop('Signal_Strength',axis=1)

# Target variable
Y=signal_df['Signal_Strength']

# %%
X.shape
# Out:
# (1359, 11)

# %%
Y.shape
# Out:
# (1359,)

# %%
# Applying the function to convert field Y from numeric to categorical (one-hot encoding)
from keras.utils import to_categorical
YC = to_categorical(Y, num_classes=8)

# %% [markdown]
# Part A - Q2 B - Split the data into train & test with 70:30 proportion.

# %%
# Split the data into train & test (categorical now) with 70:30 proportion.
from sklearn.model_selection import train_test_split
X_train, X_test, YC_train, YC_test = train_test_split(X, YC, test_size=.30, random_state=42)
# Random_state is used to set the seed for the random generator,
# so that we can ensure that the results that we get can be reproduced.

# %% [markdown]
# Part A - Q2 C - Print shape of all the 4 variables and verify if train and test data is in sync.

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of X_test :", X_test.shape)
# Out:
# Shape of X_train: (951, 11)
# Shape of X_test : (408, 11)

# %%
print("Shape of YC_train:", YC_train.shape)
print("Shape of YC_test :", YC_test.shape)
# Out:
# Shape of YC_train: (951, 8)
# Shape of YC_test : (408, 8)

# %% [markdown]
# Part A - Q2 D - Normalise the train and test data with appropriate method.

# %% [markdown]
# Normalization: Normalization involves scaling the features of the dataset to a standard range. One popular technique is Min-Max scaling, which scales the data to a specific range, often between 0 and 1, using the minimum and maximum values of the feature.

# %%
from sklearn.preprocessing import StandardScaler

# Scaling train data
X_Train_S = StandardScaler().fit_transform(X_train)

# Scaling test data
X_Test_S = StandardScaler().fit_transform(X_test)

# %%
print(X_Train_S)
# Out:
# [[ 2.49277047 -0.68331292  1.8291926  ... -2.03349188  1.18660005
#    0.36053597]
#  [ 0.563267   -0.39138543 -0.21861594 ... -1.0794293  -1.00941055
#   -0.94753268]
#  [ 2.49277047 -0.39138543  1.8291926  ... -2.16978653  1.62580216
#   -0.20006488]
#  ...
#  [-0.90683088 -0.33299994 -0.98654415 ... -0.05721939  0.0153944
#   -0.76066573]
#  [ 0.37950476 -1.2087824   0.19094577 ... -0.94313464 -0.71660914
#   -0.01319793]
#  [ 0.50201292 -1.0920114   0.75409311 ... -0.87498732 -0.71660914
#    0.92113683]]

# %%
print(X_Test_S)
# Out:
# [[-0.34551551  0.47449258 -1.18476779 ...  0.19073314 -0.89804615
#   -0.90029215]
#  [-0.0539533   0.55332778 -0.87746629 ... -0.12754548  0.68530923
#    0.40883478]
#  [ 0.06267158 -0.83942742  0.81269195 ... -0.89141416  1.11713342
#    0.68936198]
#  ...
#  [ 0.35423379  0.31682218  0.60782429 ...  0.38170032 -0.53819265
#   -0.15221962]
#  [ 0.93735821 -1.10221142  1.47851187 ... -1.01872561  0.54136783
#    0.87638011]
#  [ 1.0539831  -1.15476823  0.40295662 ... -0.4458241   1.26107482
#    0.68936198]]

# %% [markdown]
# Part A - Q2 E - Transform Labels into format acceptable by Neural Network

# %% [markdown]
# This has already been covered above, where the label is converted to a categorical field. One-hot encoding is done here for the target variable Y (label). This has been done before the train test split (refer above).
# Copying the code from above and commenting it, as it is executed above.

# %%
# Applying the function to convert field Y from numeric to categorical (one-hot encoding)
# from keras.utils import to_categorical
# YC = to_categorical(Y, num_classes=8)

# %% [markdown]
# Part A - Q3 A - Design a Neural Network to train a classifier.

# %%
from keras.models import Sequential # Forward Propagation
# Forward propagation is the way data moves from left (input layer) to
# right (output layer) in the neural network.

from keras.layers import Dense, Activation, LeakyReLU
# Activations can be used through an Activation layer
# Dense Layer is simple layer of neurons in which each neuron receives input
# from all the neurons of previous layer, thus called as dense.

# An Activation Function decides whether a neuron should be activated or not.
# This means that it will decide whether the neuron's input to the network is
# important or not in the process of prediction using simpler mathematical
# operations.

# Leaky ReLU is an activation function used in artificial neural networks to
# introduce nonlinearity among the outputs between layers of a neural network.

from keras import optimizers

# Optimizers are algorithms or methods used to change the attributes of your
# neural network such as weights and learning rate in order to reduce the
# losses.

# %%
# Initializes the neural network model
model = Sequential()

# %% [markdown]
# A Sequential model is appropriate for a plain stack of layers where each layer has exactly one input tensor and one output tensor.

# %%
# Layer that adds a list of inputs.
model.add(Dense(64, activation='relu', input_shape=(11,)))  # Input layer which has 11 input parameters

# %% [markdown]
# The input layer has 11 input parameters.

# %% [markdown]
# Keras Dense layer is the layer that contains all the neurons that are deeply connected within themselves. This means that every neuron in the dense layer takes the input from all the other neurons of the previous layer.

# %% [markdown]
# Activation function used here is 'relu'.                                     The ReLU activation function is used to introduce nonlinearity in a neural network, helping mitigate the vanishing gradient problem during machine learning model training and enabling neural networks to learn more complex relationships in data.

# %%
model.add(Dense(32, activation='relu'))  # Hidden layer 1
model.add(Dense(16, activation='relu'))  # Hidden layer 2

# %%
model.add(Dense(8, activation='softmax'))  # Output layer which will have 8 neurons for 8 classes (Signal_strength has values 3,4,5,6,7,8)

# %%
# Compile the model
model.compile(optimizer='adam', loss='CategoricalCrossentropy', metrics=['accuracy'])

# %% [markdown]
# Compile configures the model for training. The optimizer 'adam' is used.      The Adam optimizer, short for “Adaptive Moment Estimation,” is an iterative optimization algorithm used to minimize the loss function during the training of neural networks. Adam can be looked at as a combination of RMSprop and Stochastic Gradient Descent with momentum.

# %%
# Prints a summary of the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 8)                 136
#
# ...
# Total params: 3512 (13.72 KB)
# Trainable params: 3512 (13.72 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# The model.summary() prints a useful summary of the model, which includes:     a. Name and type of all layers in the model.
# b. Output shape for each layer.
# c. Number of weight parameters of each layer.
# d. The total number of trainable and non-trainable parameters of the model.

# %% [markdown]
# Part A - Q3 B - Train the classifier using previously designed Architecture

# %% [markdown]
# Verify the shapes of the target and output tensors:

# %%
print(f"Target shape: {YC_train.shape}")
print(f"Output shape: {model.output.shape}")
# Out:
# Target shape: (951, 8)
# Output shape: (None, 8)

# %% [markdown]
# Check, if the number of classes in the target and output tensors match. This needs to match.

# %%
num_classes = YC_train.shape[1]
assert num_classes == model.output.shape[-1], "Number of classes mismatch"

# %%
print(model.layers[-1].units)
print(num_classes)
# Out:
# 8
# 8

# %% [markdown]
# Change the number of classes in the output layer of the model, in case of mismatch.

# %%
model.layers[-1].units = num_classes

# %% [markdown]
# Re-verify the number of classes in the target and output tensors.

# %%
print(model.layers[-1].units)
print(num_classes)
# Out:
# 8
# 8

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Categorical Cross Entropy is also known as Softmax Loss. It's a softmax activation plus a Cross-Entropy loss used for multiclass classification.
# Using this loss, we can train a Convolutional Neural Network to output a probability over the N classes for each image.

# %% [markdown]
# Categorical Cross Entropy: Used as a loss function for multi-class classification model, where there are two or more output labels. The output label is assigned one-hot category encoding value in form of 0s and 1. The output label, if present in integer form, is converted into categorical encoding using keras.

# %%
model_classifier=model.fit(X_Train_S, YC_train, validation_data=(X_Test_S,YC_test), epochs=50, batch_size=32)
# The fit() method helps in fitting the training dataset into an estimator (ML algorithms).
# Batch Size: The number of training samples used in one iteration.
# Epoch: one full cycle through the training dataset. A cycle is composed of many iterations.
# Here, keeping epochs at 50 and batch_size at 32.
# Out:
# Epoch 1/50
# 30/30 [==============================] - 2s 11ms/step - loss: 1.8886 - accuracy: 0.3344 - val_loss: 1.6488 - val_accuracy: 0.4216
# Epoch 2/50
# 30/30 [==============================] - 0s 3ms/step - loss: 1.4781 - accuracy: 0.4290 - val_loss: 1.3249 - val_accuracy: 0.4485
# Epoch 3/50
# 30/30 [==============================] - 0s 3ms/step - loss: 1.2251 - accuracy: 0.5016 - val_loss: 1.1259 - val_accuracy: 0.5858
# Epoch 4/50
# 30/30 [==============================] - 0s 4ms/step - loss: 1.0677 - accuracy: 0.5668 - val_loss: 1.0302 - val_accuracy: 0.5956
# Epoch 5/50
# 30/30 [==============================] - 0s 4ms/step - loss: 0.9957 - accuracy: 0.5825 - val_loss: 0.9807 - val_accuracy: 0.6029
# Epoch 6/50
# 30/30 [==============================] - 0s 3ms/step - loss: 0.9567 - accuracy: 0.5752 - val_loss: 0.9658 - val_accuracy: 0.5956
# Epoch 7/50
# ...

# %% [markdown]
# Model fitting is a measure of how well a machine learning model generalizes to similar data to that on which it was trained. A model that is well-fitted produces more accurate outcomes.

# %% [markdown]
# Here, 50 is the size of the training set. Field batch_size = 32

# %% [markdown]
# loss and acc refer to the current loss and accuracy of the training set. At the end of each epoch, your trained neural network is evaluated against your validation set. This is what val_loss and val_acc refer to.

# %% [markdown]
# The model_classifier object returned by model.fit() is a simple class with some fields, e.g. a reference to the model, a params dict and, most importantly, a model_classifier dict. It stores the values of loss and acc (or any other used metric) at the end of each epoch.

# %% [markdown]
# Part A - Q3 C - Plot 2 separate visuals. i. Training Loss and Validation Loss ii. Training Accuracy and Validation Accuracy

# %% [markdown]
# The training loss indicates how well the model is fitting the training data, while the validation loss indicates how well the model fits new data

# %% [markdown]
# Training is the process of adjusting the parameters of a neural network to minimize a cost function. Validation is the process of measuring the accuracy of a model on a subset of the data. Accuracy is a measure of how well a model is able to predict the correct output given the input.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(11, 5))

# Plots training loss and validation loss
plt.subplot(1, 2, 1)
plt.plot(model_classifier.history['loss'], label='Training Loss')
plt.plot(model_classifier.history['val_loss'], label='Validation Loss')
plt.title('Training Loss vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plots training accuracy and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(model_classifier.history['accuracy'], label='Training Accuracy')
plt.plot(model_classifier.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training Accuracy vs Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Part A - Q3 D - Design new architecture/update existing architecture in attempt to improve the performance of the model.

# %%
# !pip install tensorflow
import tensorflow as tf
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential

# %%
# Define a new model with dropout layers
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(11,)))
model.add(Dropout(0.5))
# Here we can see the dropout parameter as 0.5 which means that half of the given units will drop out.
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
print(f"y_pred shape: {model.predict(X_Test_S).shape}")
print(f"y_true shape: {YC_test.shape}")
# Out:
# 13/13 [==============================] - 0s 5ms/step
# y_pred shape: (408, 8)
# y_true shape: (408, 8)

# %%
model.layers[-1] = tf.keras.layers.Dense(8, activation='softmax')

# %%
# Train the classifier with the updated architecture
model_classifier=model.fit(X_Train_S, YC_train, validation_data=(X_Test_S,YC_test), epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 30/30 [==============================] - 1s 10ms/step - loss: 2.3443 - accuracy: 0.1241 - val_loss: 1.8984 - val_accuracy: 0.4142
# Epoch 2/50
# 30/30 [==============================] - 0s 3ms/step - loss: 1.8839 - accuracy: 0.3165 - val_loss: 1.6133 - val_accuracy: 0.5392
# Epoch 3/50
# 30/30 [==============================] - 0s 3ms/step - loss: 1.6158 - accuracy: 0.4259 - val_loss: 1.3736 - val_accuracy: 0.5466
# Epoch 4/50
# 30/30 [==============================] - 0s 4ms/step - loss: 1.4621 - accuracy: 0.4858 - val_loss: 1.2300 - val_accuracy: 0.5539
# Epoch 5/50
# 30/30 [==============================] - 0s 4ms/step - loss: 1.3620 - accuracy: 0.4900 - val_loss: 1.1391 - val_accuracy: 0.5490
# Epoch 6/50
# 30/30 [==============================] - 0s 4ms/step - loss: 1.2726 - accuracy: 0.5163 - val_loss: 1.0803 - val_accuracy: 0.5686
# Epoch 7/50
# ...

# %% [markdown]
# Part A - Q3 E - Plot visuals as in Q3.C and share insights about difference observed in both the models.

# %%
plt.figure(figsize=(11, 5))

# Plots training loss and validation loss
plt.subplot(1, 2, 1)
plt.plot(model_classifier.history['loss'], label='Training Loss')
plt.plot(model_classifier.history['val_loss'], label='Validation Loss')
plt.title('Training v/s Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Plots training accuracy and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(model_classifier.history['accuracy'], label='Training Accuracy')
plt.plot(model_classifier.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training v/s Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Insights about differences observed in both models

# %% [markdown]
# Training Loss vs Validation Loss:
#
# The Original Model (First Model):
#
# Epoch 1/50
# 30/30 [==============================] - 1s 11ms/step - loss: 1.8234 - accuracy: 0.3596 - val_loss: 1.5058 - val_accuracy: 0.4608
#
# Epoch 50/50
# 30/30 [==============================] - 0s 7ms/step - loss: 0.6015 - accuracy: 0.7508 - val_loss: 1.1044 - val_accuracy: 0.5735
#
# Initially, there was a 1.8234 training loss and a 1.5058 validation loss.
# After that, the training loss and validation loss eventually dropped to 0.6015 and 1.1044, respectively.
# Over epochs, a discrepancy between training and validation loss has been observed.
#
#
# The Updated Model (Second Model):
#
# Epoch 1/50
# 30/30 [==============================] - 1s 10ms/step - loss: 2.1770 - accuracy: 0.1619 - val_loss: 1.7495 - val_accuracy: 0.4118
#
# Epoch 50/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.9728 - accuracy: 0.5689 - val_loss: 0.9007 - val_accuracy: 0.6299
#
# At first, there was a 2.1770 training loss and a 1.7495 validation loss.
# After then, the training loss and validation loss numbers gradually dropped until they eventually achieved 0.9728 and 0.9007, respectively.
# The difference between the training and validation losses is consistently smaller than it was with the original model.

# %% [markdown]
# Training vs. Validation Accuracy:
#
# The Original Model (First Model):
#
# Epoch 1/50 30/30 [==============================] - 1s 11ms/step - loss: 1.8234 - accuracy: 0.3596 - val_loss: 1.5058 - val_accuracy: 0.4608
#
# Epoch 50/50 30/30 [==============================] - 0s 7ms/step - loss: 0.6015 - accuracy: 0.7508 - val_loss: 1.1044 - val_accuracy: 0.5735
#
# Starting at 0.3596 and 0.4608, respectively, were the training and validation accuracy.
# For training and validation accuracy, this value has grown across epochs to final values of 0.7508 and 0.5735, respectively.
# Across all epochs, there has been a constant discrepancy in the accuracy of training and validation.
#
# The Updated Model (Second Model):
#
# Epoch 1/50
# 30/30 [==============================] - 1s 10ms/step - loss: 2.1770 - accuracy: 0.1619 - val_loss: 1.7495 - val_accuracy: 0.4118
#
# Epoch 50/50
# 30/30 [==============================] - 0s 10ms/step - loss: 0.9728 - accuracy: 0.5689 - val_loss: 0.9007 - val_accuracy: 0.6299
#
#
# The initial values for the training and validation accuracy were 0.1619 and 0.4118, respectively.
# The ultimate values of 0.5689 and 0.6299, respectively, are the result of this value increasing across epochs.
# The difference between the accuracy of the training and validation phases is less than it was for the original model.

# %% [markdown]
# Insights:
#
# Overfitting symptoms have been seen in both models. The revised model showed advantages in lessening the tendency to overfit. Compared to the original model, the modified model shows a steady confluence of the validation and training measures.
#
# In comparison to the original model, the revised model showed a firmer convergence of training and validation measures, indicating improved generalization.
# (Generalization is the capacity of the model to appropriately adjust to new, never-before-seen data that is taken from the same distribution as the model itself. Have a gut feeling about overfitting. Ascertain the quality of a model. Create training and test sets from a given data collection.
#
# Even if the difference in metrics has shrunk, there is still room for improvement in the updated model's ability to reduce overfitting even more and enhance generalization.
